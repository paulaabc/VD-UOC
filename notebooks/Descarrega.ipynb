# %% [markdown]
# Codi per descarregar les dades de l'API de Steam, usant el dataset de jocs del 2025
#
# El datset incial del jocs s'ha obtingut de Kaggle: https://www.kaggle.com/datasets/srgiomanhes/steam-games-dataset-2025

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import requests
import pandas as pd
import time
import json
from typing import Dict, List, Optional
import os
from datetime import datetime
import concurrent.futures
import threading
from queue import Queue

class SteamAchievementsCollector:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "http://api.steampowered.com"
        self.session = requests.Session()

    def get_all_game_data(self, appid: int, game_data: dict) -> List[dict]:
        """Obté tots els assoliments i reviews d'un joc en una sola funció"""
        url = f"{self.base_url}/ISteamUserStats/GetGlobalAchievementPercentagesForApp/v0000002/"
        params = {'gameid': appid, 'format': 'json'}

        try:
            response = self.session.get(url, params=params, timeout=10)
            if response.status_code != 200:
                return []

            data = response.json()
            if 'achievementpercentages' not in data:
                return []

            achievements = data['achievementpercentages']['achievements']

            # Crear registres per tots els assoliments
            result = []
            for achievement in achievements:
                achievement_data = {
                    'steam_appid': appid,
                    'game_name': game_data['name'],
                    'achievement_name': achievement['name'],
                    'achievement_percent': achievement['percent'],
                    'developers': game_data['developers'],
                    'publishers': game_data['publishers'],
                    'categories': game_data['categories'],
                    'genres': game_data['genres'],
                    'required_age': game_data['required_age'],
                    'n_achievements': game_data['n_achievements'],
                    'platforms': game_data['platforms']
                }
                result.append(achievement_data)

            return result

        except:
            return []

    def process_batch(self, games_batch: List[tuple], delay: float = 0.3) -> List[dict]:
        """Processa un lot de jocs"""
        all_achievements = []

        for appid, game_data in games_batch:
            achievements = self.get_all_game_data(appid, game_data)
            all_achievements.extend(achievements)
            time.sleep(delay)

        return all_achievements

    def collect_achievements_data(self, steam_df: pd.DataFrame,
                                 delay: float = 0.3,
                                 batch_size: int = 200,
                                 save_path: str = '/content/drive/MyDrive/GoogleColab/') -> pd.DataFrame:

        games_with_achievements = steam_df[
            (steam_df['n_achievements'] > 0) &
            (steam_df['is_released'] == True)
        ].copy().reset_index(drop=True)

        total_games = len(games_with_achievements)
        print(f"Processant {total_games} jocs")

        # Preparar dades
        games_data = []
        for idx, game in games_with_achievements.iterrows():
            games_data.append((game['steam_appid'], game.to_dict()))

        all_achievements = []
        processed = 0

        # Processar en lots
        for i in range(0, len(games_data), batch_size):
            batch = games_data[i:i+batch_size]
            batch_achievements = self.process_batch(batch, delay)
            all_achievements.extend(batch_achievements)

            processed += len(batch)
            print(f"Progres: {processed}/{total_games} ({len(all_achievements)} assoliments)")

            # Guardar progres
            if processed % 500 == 0 or processed >= total_games:
                temp_df = pd.DataFrame(all_achievements)
                progress_file = os.path.join(save_path, 'steam_achievements_progress.csv')
                temp_df.to_csv(progress_file, index=False)

        # Guardar resultat final
        final_df = pd.DataFrame(all_achievements)
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        final_filename = f'steam_achievements_complete_{timestamp}.csv'
        final_path = os.path.join(save_path, final_filename)
        final_df.to_csv(final_path, index=False)

        print(f"Guardat: {final_filename}")
        print(f"Total assoliments: {len(final_df):,}")
        print(f"Jocs processats: {final_df['steam_appid'].nunique():,}")

        return final_df

def main():
    API_KEY = "XXXXXXXXXXXXXXXXXXXXXXXXXX" # canviar la clau de la API per una pròpia, l'he modificat per seguretat
    dataset_path = '/steam_games.csv' # path del dataset on son els jocs, modificar per el pròpi
    save_path = '/GoogleColab/'  # path on guardar dataset dels assoliments, modificar per el pròpi

    steam_df = pd.read_csv(dataset_path)
    collector = SteamAchievementsCollector(API_KEY)

    # Delay
    achievements_df = collector.collect_achievements_data(
        steam_df,
        delay=0.3,
        batch_size=200,
        save_path=save_path
    )

if __name__ == "__main__":
    main()
# Out:
# Processant 31533 jocs
# Progres: 200/31533 (3789 assoliments)
# Progres: 400/31533 (8590 assoliments)
# Progres: 600/31533 (12888 assoliments)
# Progres: 800/31533 (17091 assoliments)
# Progres: 1000/31533 (21360 assoliments)
# Progres: 1200/31533 (25754 assoliments)
# Progres: 1400/31533 (29834 assoliments)
# Progres: 1600/31533 (33707 assoliments)
# Progres: 1800/31533 (38213 assoliments)
# Progres: 2000/31533 (42392 assoliments)
# Progres: 2200/31533 (46604 assoliments)
# Progres: 2400/31533 (50839 assoliments)
# Progres: 2600/31533 (56249 assoliments)
# Progres: 2800/31533 (61242 assoliments)
# Progres: 3000/31533 (66614 assoliments)
# Progres: 3200/31533 (71586 assoliments)
# Progres: 3400/31533 (76537 assoliments)
# Progres: 3600/31533 (81920 assoliments)
# Progres: 3800/31533 (86540 assoliments)
# Progres: 4000/31533 (90979 assoliments)
# Progres: 4200/31533 (96095 assoliments)
# Progres: 4400/31533 (100901 assoliments)
# Progres: 4600/31533 (105925 assoliments)
# Progres: 4800/31533 (110964 assoliments)
# Progres: 5000/31533 (120941 assoliments)
# Progres: 5200/31533 (136379 assoliments)
# Progres: 5400/31533 (181021 assoliments)
# Progres: 5600/31533 (190673 assoliments)
# Progres: 5800/31533 (195147 assoliments)
# Progres: 6000/31533 (199549 assoliments)
# Progres: 6200/31533 (203914 assoliments)
# Progres: 6400/31533 (207846 assoliments)
# Progres: 6600/31533 (212352 assoliments)
# Progres: 6800/31533 (217221 assoliments)
# Progres: 7000/31533 (221605 assoliments)
# Progres: 7200/31533 (226010 assoliments)
# Progres: 7400/31533 (230786 assoliments)
# Progres: 7600/31533 (234958 assoliments)
# Progres: 7800/31533 (239485 assoliments)
# Progres: 8000/31533 (243782 assoliments)
# Progres: 8200/31533 (248175 assoliments)
# Progres: 8400/31533 (252871 assoliments)
# Progres: 8600/31533 (257150 assoliments)
# Progres: 8800/31533 (260699 assoliments)
# Progres: 9000/31533 (266174 assoliments)
# Progres: 9200/31533 (271230 assoliments)
# Progres: 9400/31533 (277416 assoliments)
# Progres: 9600/31533 (283652 assoliments)
# Progres: 9800/31533 (290046 assoliments)
# Progres: 10000/31533 (295815 assoliments)
# Progres: 10200/31533 (302296 assoliments)
# Progres: 10400/31533 (311730 assoliments)
# Progres: 10600/31533 (319378 assoliments)
# Progres: 10800/31533 (327669 assoliments)
# Progres: 11000/31533 (335416 assoliments)
# Progres: 11200/31533 (339059 assoliments)
# Progres: 11400/31533 (343398 assoliments)
# Progres: 11600/31533 (346971 assoliments)
# Progres: 11800/31533 (351391 assoliments)
# Progres: 12000/31533 (355393 assoliments)
# Progres: 12200/31533 (360212 assoliments)
# Progres: 12400/31533 (364205 assoliments)
# Progres: 12600/31533 (368356 assoliments)
# Progres: 12800/31533 (372383 assoliments)
# Progres: 13000/31533 (376827 assoliments)
# Progres: 13200/31533 (380900 assoliments)
# Progres: 13400/31533 (385571 assoliments)
# Progres: 13600/31533 (389863 assoliments)
# Progres: 13800/31533 (394255 assoliments)
# Progres: 14000/31533 (398505 assoliments)
# Progres: 14200/31533 (403087 assoliments)
# Progres: 14400/31533 (407361 assoliments)
# Progres: 14600/31533 (412710 assoliments)
# Progres: 14800/31533 (417909 assoliments)
# Progres: 15000/31533 (423232 assoliments)
# Progres: 15200/31533 (427915 assoliments)
# Progres: 15400/31533 (433258 assoliments)
# Progres: 15600/31533 (438984 assoliments)
# Progres: 15800/31533 (444168 assoliments)
# Progres: 16000/31533 (451462 assoliments)
# Progres: 16200/31533 (456160 assoliments)
# Progres: 16400/31533 (462086 assoliments)
# Progres: 16600/31533 (470888 assoliments)
# Progres: 16800/31533 (476262 assoliments)
# Progres: 17000/31533 (480939 assoliments)
# Progres: 17200/31533 (485541 assoliments)
# Progres: 17400/31533 (489260 assoliments)
# Progres: 17600/31533 (493491 assoliments)
# Progres: 17800/31533 (497947 assoliments)
# Progres: 18000/31533 (502012 assoliments)
# Progres: 18200/31533 (506735 assoliments)
# Progres: 18400/31533 (511047 assoliments)
# Progres: 18600/31533 (515319 assoliments)
# Progres: 18800/31533 (519806 assoliments)
# Progres: 19000/31533 (524957 assoliments)
# Progres: 19200/31533 (529695 assoliments)
# Progres: 19400/31533 (534589 assoliments)
# Progres: 19600/31533 (538597 assoliments)
# Progres: 19800/31533 (567085 assoliments)
# Progres: 20000/31533 (604946 assoliments)
# Progres: 20200/31533 (645493 assoliments)
# Progres: 20400/31533 (661692 assoliments)
# Progres: 20600/31533 (676416 assoliments)
# Progres: 20800/31533 (692598 assoliments)
# Progres: 21000/31533 (698503 assoliments)
# Progres: 21200/31533 (706706 assoliments)
# Progres: 21400/31533 (716247 assoliments)
# Progres: 21600/31533 (722769 assoliments)
# Progres: 21800/31533 (742883 assoliments)
# Progres: 22000/31533 (747993 assoliments)
# Progres: 22200/31533 (753931 assoliments)
# Progres: 22400/31533 (759221 assoliments)
# Progres: 22600/31533 (765118 assoliments)
# Progres: 22800/31533 (771250 assoliments)
# Progres: 23000/31533 (776618 assoliments)
# Progres: 23200/31533 (781697 assoliments)
# Progres: 23400/31533 (786983 assoliments)
# Progres: 23600/31533 (792788 assoliments)
# Progres: 23800/31533 (798312 assoliments)
# Progres: 24000/31533 (803765 assoliments)
# Progres: 24200/31533 (809742 assoliments)
# Progres: 24400/31533 (816085 assoliments)
# Progres: 24600/31533 (824603 assoliments)
# Progres: 24800/31533 (834419 assoliments)
# Progres: 25000/31533 (839025 assoliments)
# Progres: 25200/31533 (850386 assoliments)
# Progres: 25400/31533 (856240 assoliments)
# Progres: 25600/31533 (872505 assoliments)
# Progres: 25800/31533 (888076 assoliments)
# Progres: 26000/31533 (904062 assoliments)
# Progres: 26200/31533 (909823 assoliments)
# Progres: 26400/31533 (916678 assoliments)
# Progres: 26600/31533 (923683 assoliments)
# Progres: 26800/31533 (931278 assoliments)
# Progres: 27000/31533 (958142 assoliments)
# Progres: 27200/31533 (971722 assoliments)
# Progres: 27400/31533 (986241 assoliments)
# Progres: 27600/31533 (994836 assoliments)
# Progres: 27800/31533 (1014585 assoliments)
# Progres: 28000/31533 (1021810 assoliments)
# Progres: 28200/31533 (1029635 assoliments)
# Progres: 28400/31533 (1036901 assoliments)
# Progres: 28600/31533 (1049617 assoliments)
# Progres: 28800/31533 (1070239 assoliments)
# Progres: 29000/31533 (1079761 assoliments)
# Progres: 29200/31533 (1085205 assoliments)
# Progres: 29400/31533 (1090874 assoliments)
# Progres: 29600/31533 (1097249 assoliments)
# Progres: 29800/31533 (1102798 assoliments)
# Progres: 30000/31533 (1110684 assoliments)
# Progres: 30200/31533 (1116961 assoliments)
# Progres: 30400/31533 (1124232 assoliments)
# Progres: 30600/31533 (1130564 assoliments)
# Progres: 30800/31533 (1136328 assoliments)
# Progres: 31000/31533 (1141939 assoliments)
# Progres: 31200/31533 (1147417 assoliments)
# Progres: 31400/31533 (1152750 assoliments)
# Progres: 31533/31533 (1156256 assoliments)
# Guardat: steam_achievements_complete_20250528_214709.csv
# Total assoliments: 1,156,256
# Jocs processats: 31,507
